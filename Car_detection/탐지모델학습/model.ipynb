# %% [markdown]
# dataset_one 학습
# https://www.kaggle.com/datasets/ajaykumar254/top-view-vehicle-detection-image-dataset

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov5s.pt")
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/drive/MyDrive/졸작/dataset_one/data.yaml"

# %%
model.train(
    data=dataset_path,
    epochs=50,
    imgsz=640,
    batch=16,
    workers=4,
    device=0,
    name="vehicle_train"   # 학습 결과 폴더 이름 지정
)
# Out:
# Ultralytics 8.3.189 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp runs/detect/vehicle_train/weights/best.pt /content/drive/MyDrive/best_s.pt
# !cp runs/detect/vehicle_train/weights/last.pt /content/drive/MyDrive/last_s.pt

# %% [markdown]
# dataset_two 학습
#
# https://www.kaggle.com/datasets/glebkuzntesov/top-view-drone-car-detection-dataset-12000-images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# 학습된 best 모델 불러오기
model = YOLO("/content/drive/MyDrive/best_s.pt")

# %%
model.train(
    data="/content/drive/MyDrive/졸작/dataset_two/dataset.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    device=0,
    name="dataset_two_train"  # 저장 폴더 이름 지정
)
# Out:
# Ultralytics 8.3.195 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.train(
    data="/content/drive/MyDrive/졸작/dataset_two/dataset.yaml",
    epochs=20,
    imgsz=640,
    batch=16,
    device=0,
    project="/content/drive/MyDrive/졸작/train_results",  # Drive에 직접 저장
    name="dataset_two_train",
    exist_ok=True
)
# Out:
# Ultralytics 8.3.196 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
